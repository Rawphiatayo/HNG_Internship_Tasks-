# %%
! pip install google-search-results
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32224 sha256=784cb768d354eb6531306b189382a0985981688b2f53627a1986a4d9706c5bdb
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\ec\68\6c\3fc2479ee7b507f81bbfd03a99f0c1e28834cb5a5af8e8ac3f
# Successfully built google-search-results
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from serpapi import GoogleSearch
import pandas as pd
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from serperapi import GoogleSearch
#       2 import pandas as pd
#       3 import time
#
# ModuleNotFoundError: No module named 'serperapi'

# %%
api key= "77e1c6db1fe00be85540f8daefaf0d27dd2c4356"
# Out:
#   Cell In[4], line 1
#     api key= "77e1c6db1fe00be85540f8daefaf0d27dd2c4356"
#         ^
# SyntaxError: invalid syntax
